# %%
# 导入数据
import pandas as pd

# %%
text_ana = pd.read_excel(r'D:\strong\text_analysis_weibo_sample.xlsx')

# %%
text_ana
# Out:
#     Unnamed: 0  index                                            标题/微博内容  点赞  \
# 0            0  34121    国债：地产行业重磅利好提振风险偏好，期债低开低走     国债期货全线收跌，10年期主力...   0
# 1            1  40230                                      #喜迎二十大 忠诚保平安#   0
# 2            2   7714  注意！事关明日教资考试！福建省教育考试院发布补充公告  福建省2022年下半年全国中小学教师...   0
# 3            3  27378                     近日，“千年大计”雄安新区迎来五周岁生日。从“一张白纸...   0
# 4            4  15435                                             樊振东牛逼！   0
# ..         ...    ...                                                ...  ..
# 95          95  14034                                          老公好漂亮[舔屏]   0
# 96          96  35249  恭喜@张小娜呀娜 1名用户获得【小飞T】。C官方唯一抽奖工具@C抽奖平台 对本次抽奖进行监督...   0
# 97          97  39598  接不动了，居民部门负债率提升空间太有限了。现在动辄几万一平米，总价高，月供高，预期转差，还怎...   0
# 98          98  48977     目前电子烟政策已从制定阶段逐渐走向实施阶段，而主要的电子烟公司股价下跌幅度高达70%-...   0
# 99          99  24863                          你们家的小编真的很用心,关注不后悔[话筒][话筒]   0
#
#     转发  评论                         账号昵称UID加密     粉丝数   关注数  地域
# 0    0   0  e5df796860e68f403bcf9651bab4d42e       0     0  其他
# 1    0   0  6e35cb69ad52f20de5e28197b2e85306  405444   252  广西
# 2    0   0  e6953217442e6c06a7af23eee5e185f2   53264  2177  福建
# 3    0   0                               NaN       0     0  北京
# 4    0   0  344af41eac516375c04dee6325e763cc       8    51  山东
# ..  ..  ..                               ...     ...   ...  ..
# 95   0   0  aa7af97ae98cbe8983e559b948ecfabf     825   191  北京
# 96   0   2  f538513e5801c275cbcf285517a8ee62   51709    20  北京
# 97   0   0  2e76c39b6665a0b6f5bdc4c35f36f573       0    59  四川
# 98   0   0                               NaN       0     0  北京
# 99   0   0  66b5a5927727e304d69abc8028d3b50a       7    83  山东
#
# [100 rows x 10 columns]

# %%
text_ana = text_ana.drop(['Unnamed: 0'],axis=1)

# %%
# 分析语料
text_ana[['标题/微博内容']]
# Out:
#                                               标题/微博内容
# 0     国债：地产行业重磅利好提振风险偏好，期债低开低走     国债期货全线收跌，10年期主力...
# 1                                       #喜迎二十大 忠诚保平安#
# 2   注意！事关明日教资考试！福建省教育考试院发布补充公告  福建省2022年下半年全国中小学教师...
# 3                      近日，“千年大计”雄安新区迎来五周岁生日。从“一张白纸...
# 4                                              樊振东牛逼！
# ..                                                ...
# 95                                          老公好漂亮[舔屏]
# 96  恭喜@张小娜呀娜 1名用户获得【小飞T】。C官方唯一抽奖工具@C抽奖平台 对本次抽奖进行监督...
# 97  接不动了，居民部门负债率提升空间太有限了。现在动辄几万一平米，总价高，月供高，预期转差，还怎...
# 98     目前电子烟政策已从制定阶段逐渐走向实施阶段，而主要的电子烟公司股价下跌幅度高达70%-...
# 99                          你们家的小编真的很用心,关注不后悔[话筒][话筒]
#
# [100 rows x 1 columns]

# %%
# !pip install jieba
import jieba
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ---------------------------------------- 19.2/19.2 MB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: jieba
#   Building wheel for jieba (setup.py): started
#   Building wheel for jieba (setup.py): finished with status 'done'
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314459 sha256=6ece27b2033fc5f0f8467d268c740658c2db16639552620bdf3681aef90d7d9a
#   Stored in directory: c:\users\shang shichen\appdata\local\pip\cache\wheels\7d\74\cf\08c94db4b784e2c1ef675a600b7b5b281fd25240dcb954ee7e
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %%
def word_segmentation(text):
    words = jieba.cut(text,cut_all = False)
    return ' '.join(words)

text_ana['标题/微博内容'] = text_ana['标题/微博内容'].apply(word_segmentation)
text_ana[['标题/微博内容']]
# Out:
#                                               标题/微博内容
# 0                                   国债            ...
# 1   #               喜迎               二十大          ...
# 2   注意               ！               事关           ...
# 3                                                 ...
# 4   樊振东               牛               逼           ...
# ..                                                ...
# 95  老公               好               漂亮           ...
# 96  恭喜               @               张小娜          ...
# 97  接不动               了               ，           ...
# 98                                                ...
# 99  你们               家               的            ...
#
# [100 rows x 1 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# 初始化CountVectorizer
vectorizer = CountVectorizer()

# %%
# 将文本数据转化为词袋特征矩阵
X = vectorizer.fit_transform(text_ana['标题/微博内容'].dropna())

# %%
# 展示特征矩阵的形状
print('词袋特征矩阵的形状:', X.shape)
# Out:
# 词袋特征矩阵的形状: (100, 5788)

# %%
# 展示词袋模型中的所有特征词
print('特征词列表:',vectorizer.get_feature_names_out())
# Out:
# 特征词列表: ['00' '000713' '000998' ... '龙头' '龙头企业' '龙湖']

# %%
len(vectorizer.get_feature_names_out())
# Out:
# 5788

# %%
X
# Out:
# <100x5788 sparse matrix of type '<class 'numpy.int64'>'
# 	with 9656 stored elements in Compressed Sparse Row format>

# %%
feature_words = vectorizer.get_feature_names_out()

# %%
feature_words.shape
# Out:
# (5788,)

# %%
X.sum(axis=0).shape
# Out:
# (1, 5788)

# %%
X.sum(axis=0)[0]
# Out:
# matrix([[6, 1, 1, ..., 2, 1, 2]], dtype=int64)

# %%
word_freq = dict(zip(feature_words, X.sum(axis=0).A1))

# %%
word_freq
# Out:
# {'00': 6,
#  '000713': 1,
#  '000998': 1,
#  '002041': 1,
#  '002385': 1,
#  '01': 10,
#  '02': 4,
#  '03': 4,
#  '04': 3,
#  '05': 4,
#  '06': 3,
#  '061': 1,
#  '07': 6,
#  '08': 4,
#  '081': 1,
#  '0824': 1,
#  '09': 16,
#  '10': 57,
#  '100': 19,
#  '1000': 5,
#  '10080': 1,
#  '101': 1,
#  '10180': 1,
#  '102': 3,
#  '1025': 1,
#  '10274': 1,
#  '10355': 1,
#  '104': 3,
#  '10410': 1,
#  '10455': 1,
#  '105': 1,
#  '10510': 1,
#  '10685': 1,
#  '107': 2,
#  '108': 1,
#  '1080': 1,
#  '10cm': 2,
#  '10g': 1,
#  '11': 49,
#  '110': 3,
#  '1100': 1,
#  '11089': 1,
#  '112': 2,
#  '115': 1,
#  '116': 1,
#  '11724': 1,
#  '1189': 1,
#  '119': 1,
#  '11998': 1,
#  '12': 37,
#  '120': 4,
#  '1200': 2,
#  '12000': 2,
#  '12010': 1,
#  '1210': 1,
#  '122': 1,
#  '12245': 1,
#  '12750': 1,
#  '1280': 1,
#  '13': 14,
#  '130': 1,
#  '13050': 1,
#  '130eflops': 1,
#  '1310': 1,
#  '131700': 1,
#  '133': 1,
#  '13300': 1,
#  '13500': 1,
#  '136': 2,
#  '1360': 1,
#  '13686': 1,
#  '13817426131': 1,
#  '1383': 3,
#  '1399': 1,
#  '14': 17,
#  '1400': 3,
#  '1420': 1,
#  '145': 1,
#  '1477': 1,
#  '14815': 1,
#  '15': 17,
#  '150': 3,
#  '1500': 6,
#  '15050': 1,
#  '15125': 1,
#  '152': 1,
#  '15200': 1,
#  '15305': 1,
#  '15390': 1,
#  '15400': 1,
#  '15459': 1,
#  '155': 1,
#  '156': 2,
#  '15780': 1,
#  '1597': 1,
#  '15cm': 1,
#  '16': 7,
#  '16200': 1,
#  '1628': 1,
#  '163': 1,
#  '1650': 1,
#  '1655': 2,
#  '1660': 1,
#  '16600': 3,
#  '1663': 1,
#  '1665': 1,
#  '1675': 3,
#  '168': 1,
#  '1680': 3,
#  '1681': 1,
#  '1685': 2,
#  '1690': 2,
#  '16900': 2,
#  '169060': 1,
#  '17': 13,
#  '1700': 1,
#  '17000': 1,
#  '171890': 1,
#  '17300': 1,
#  '1733': 1,
#  '174': 1,
#  '1749': 1,
#  '1760': 1,
#  '177': 2,
#  '18': 17,
#  '180': 4,
#  '1800': 3,
#  '181000': 1,
#  '182': 1,
#  '182650': 1,
#  '18400': 1,
#  '184300': 1,
#  '1844': 1,
#  '1850': 1,
#  '1867': 2,
#  '18730': 1,
#  '189': 1,
#  '18983967167': 1,
#  '19': 15,
#  '1900': 1,
#  '1903': 1,
#  '194': 1,
#  '195230': 1,
#  '196000': 1,
#  '197': 1,
#  '197000': 1,
#  '1980': 2,
#  '198000': 1,
#  '199': 1,
#  '20': 28,
#  '200': 10,
#  '2000': 2,
#  '20000': 1,
#  '200000': 1,
#  '2002': 1,
#  '2004': 1,
#  '2012': 1,
#  '2013': 1,
#  '2015': 1,
#  '2016': 3,
#  '2018': 2,
#  '2019': 2,
#  '2020': 21,
#  '2021': 46,
#  '2022': 56,
#  '2023': 9,
#  '2024': 5,
#  '2025': 6,
#  '203': 1,
#  '2035': 1,
#  '2050': 1,
#  '2097': 1,
#  '21': 18,
#  '210': 1,
#  '211': 2,
#  '212': 1,
#  '2141': 1,
#  '215': 3,
#  '217': 1,
#  '2173': 1,
#  '219': 1,
#  '21915': 1,
#  '22': 23,
#  '220': 2,
#  '2200': 1,
#  '2207': 1,
#  '22086': 1,
#  '2209': 8,
#  '2210': 1,
#  '222': 1,
#  '224': 1,
#  '2246': 1,
#  '2249': 1,
#  '225': 1,
#  '2250': 1,
#  '2254': 1,
#  '2272': 1,
#  '229': 1,
#  '23': 10,
#  '230': 5,
#  '2300': 1,
#  '23166': 1,
#  '2339': 1,
#  '2340': 1,
#  '23500': 1,
#  '2354': 1,
#  '23570': 1,
#  '23610': 1,
#  '23670': 1,
#  '237': 1,
#  '23710': 1,
#  '23780': 1,
#  '23850': 1,
#  '24': 20,
#  '246': 1,
#  '247': 1,
#  '249': 1,
#  '25': 28,
#  '250': 1,
#  '2500': 2,
#  '25131': 1,
#  '2519': 1,
#  '2550': 1,
#  '2566': 1,
#  '258': 1,
#  '259': 1,
#  '26': 11,
#  '2600': 1,
#  '2613': 1,
#  '2640': 1,
#  '2650': 3,
#  '2672': 1,
#  '2680': 1,
#  '27': 14,
#  '2700': 3,
#  '2710': 1,
#  '27100': 2,
#  '2720': 1,
#  '273': 1,
#  '2730': 1,
#  '274': 1,
#  '2740': 1,
#  '2745': 1,
#  '2748': 1,
#  '2750': 3,
#  '2760': 1,
#  '2766': 1,
#  '2768': 1,
#  '2780': 1,
#  '27894': 1,
#  '28': 41,
#  '280': 1,
#  '2800': 1,
#  '2847': 1,
#  '2850': 2,
#  '2860': 1,
#  '29': 12,
#  '2900': 2,
#  '293087308': 1,
#  '2950': 2,
#  '2970': 1,
#  '2izti': 1,
#  '30': 23,
#  '300': 10,
#  '3000': 1,
#  '300087': 1,
#  '302': 1,
#  '304': 3,
#  '3050': 1,
#  '3061': 1,
#  '31': 8,
#  '3100': 1,
#  '3149': 1,
#  '3150': 1,
#  '316l': 1,
#  '3180': 1,
#  '3187': 1,
#  '32': 4,
#  '320': 1,
#  '3212': 1,
#  '3221': 1,
#  '33': 6,
#  '330': 4,
#  '3300': 1,
#  '3309': 1,
#  '3346': 1,
#  '3350': 1,
#  '336': 1,
#  '3386': 1,
#  '34': 10,
#  '340': 1,
#  '3402': 1,
#  '3430': 1,
#  '3460': 1,
#  '348': 1,
#  '3480': 1,
#  '35': 13,
#  '355': 1,
#  '3581': 1,
#  '36': 9,
#  '360': 1,
#  '365': 1,
#  '366': 1,
#  '37': 10,
#  '371': 1,
#  '374': 1,
#  '38': 10,
#  '380': 1,
#  '3800': 1,
#  '3810': 1,
#  '3818': 1,
#  '384': 1,
#  '39': 2,
#  '3900': 4,
#  '391': 1,
#  '3920': 1,
#  '3950': 1,
#  '3962': 1,
#  '3970': 2,
#  '3980': 1,
#  '40': 16,
#  '400': 4,
#  '4000': 6,
#  '4030': 1,
#  '41': 5,
#  '410': 1,
#  '4100': 2,
#  '4150': 1,
#  '4160': 2,
#  '4180': 1,
#  '4195': 1,
#  '42': 6,
#  '4220': 1,
#  '4250': 1,
#  '42702': 1,
#  '4293': 1,
#  '43': 7,
#  '4318': 1,
#  '4350': 1,
#  '4356': 1,
#  '4360': 1,
#  '437': 1,
#  '43893': 1,
#  '44': 2,
#  '440': 1,
#  '4401': 1,
#  '45': 15,
#  '4500': 1,
#  '452': 2,
#  '454': 1,
#  '45759': 1,
#  '458': 1,
#  '46': 6,
#  '4600': 1,
#  '4630': 1,
#  '465': 1,
#  '4650': 1,
#  '47': 4,
#  '470': 1,
#  '4758': 1,
#  '4795': 1,
#  '48': 3,
#  '480': 1,
#  '4800': 1,
#  '489': 2,
#  '48vo2toftuc': 1,
#  '49': 3,
#  '490': 1,
#  '4905': 1,
#  '4g': 2,
#  '50': 26,
#  '500': 3,
#  '5000': 3,
#  '504': 1,
#  '51': 7,
#  '510': 1,
#  '51611261': 1,
#  '518': 1,
#  '5190': 1,
#  '52': 6,
#  '53': 11,
#  '54': 8,
#  '5428': 1,
#  '5439': 1,
#  '5450': 1,
#  '5488': 1,
#  '5498': 1,
#  '55': 5,
#  '550': 3,
#  '56': 6,
#  '57': 3,
#  '5714': 1,
#  '573': 1,
#  '57630504': 1,
#  '58': 7,
#  '5810': 1,
#  '59': 15,
#  '5960': 1,
#  '59980': 1,
#  '59990': 1,
#  '5g': 24,
#  '60': 11,
#  '600': 3,
#  '6000': 3,
#  '600t': 1,
#  '601963': 1,
#  '6054': 1,
#  '61': 3,
#  '6100': 1,
#  '615': 1,
#  '617': 1,
#  '618': 1,
#  '6189': 1,
#  '62': 7,
#  '6245': 1,
#  '63': 4,
#  '63000': 1,
#  '6329': 1,
#  '64': 8,
#  '65': 9,
#  '650': 1,
#  '6530': 1,
#  '66': 3,
#  '660': 1,
#  '6623': 1,
#  '666': 2,
#  '667': 1,
#  '67': 6,
#  '6711': 1,
#  '6714': 1,
#  '6740': 2,
#  '675': 1,
#  '676': 1,
#  '677': 1,
#  '68': 7,
#  '6850': 1,
#  '687': 1,
#  '69': 4,
#  '690': 1,
#  '70': 10,
#  '700': 1,
#  '7000': 2,
#  '7001': 1,
#  '700t': 1,
#  '701': 1,
#  '704': 1,
#  '70800': 1,
#  '71': 3,
#  '7100': 1,
#  '7176': 1,
#  '72': 15,
#  '720': 2,
#  '7200': 1,
#  '7250': 1,
#  '73': 4,
#  '7350': 1,
#  '739': 1,
#  '74': 6,
#  '7400': 1,
#  '7425': 1,
#  '746': 1,
#  '7476': 1,
#  '7493080': 1,
#  '75': 27,
#  '7500': 1,
#  '75bp': 9,
#  '76': 4,
#  '7600': 1,
#  '7640': 1,
#  '7688': 1,
#  '77': 3,
#  '770': 1,
#  '777': 1,
#  '7775': 1,
#  '779': 1,
#  '78': 7,
#  '780': 1,
#  '781371439': 1,
#  '79': 3,
#  '793': 2,
#  '796': 1,
#  '80': 4,
#  '800': 3,
#  '8000': 1,
#  '805': 1,
#  '8050': 1,
#  '8059': 1,
#  '8097': 1,
#  '81': 8,
#  '8100': 1,
#  '811': 1,
#  '8150': 1,
#  '82': 3,
#  '8200': 2,
#  '826': 1,
#  '83': 4,
#  '8300': 1,
#  '8343': 1,
#  '8392': 1,
#  '84': 2,
#  '8450': 1,
#  '85': 5,
#  '8500': 1,
#  '856': 1,
#  '86': 3,
#  '863': 1,
#  '87': 5,
#  '8720': 1,
#  '8746': 1,
#  '88': 3,
#  '89': 5,
#  '8991': 1,
#  '90': 11,
#  '9000': 2,
#  '900t': 1,
#  '9060': 1,
#  '91': 4,
#  '92': 5,
#  '920': 1,
#  '93': 10,
#  '9350': 1,
#  '936': 1,
#  '9390': 1,
#  '94': 1,
#  '94955': 1,
#  '95': 6,
#  '9500': 1,
#  '956': 1,
#  '959': 1,
#  '96': 1,
#  '9631': 1,
#  '97': 3,
#  '9750': 1,
#  '98': 1,
#  '981': 1,
#  '9880': 1,
#  '99': 4,
#  '9900': 1,
#  '995': 1,
#  'a00': 3,
#  'a669drew': 1,
#  'a6agk1h6': 1,
#  'a6aj6g9v': 1,
#  'a6fjfpec': 1,
#  'a6ih9r1e': 1,
#  'a6junhoy': 1,
#  'a6kvbqhq': 1,
#  'a6ogih6n': 1,
#  'a6sxkahg': 1,
#  'aa': 5,
#  'abs': 1,
#  'al2209': 1,
#  'alameda': 3,
#  'altimeter': 1,
#  'amber': 1,
#  'anec': 3,
#  'app': 2,
#  'ark': 2,
#  'article': 1,
#  'askolani': 1,
#  'au2210c400': 1,
#  'a股': 3,
#  'b40': 3,
#  'bopp': 1,
#  'bp': 2,
#  'btc': 1,
#  'capital': 2,
#  'cathie': 1,
#  'cdc': 1,
#  'china': 1,
#  'chsi': 1,
#  'cloudtree': 1,
#  'cn': 11,
#  'coin': 1,
#  'coinbase': 5,
#  'coinshares': 2,
#  'com': 3,
#  'cp': 3,
#  'cpi': 22,
#  'cry': 3,
#  'crypto': 1,
#  'ctp': 1,
#  'cu2209': 1,
#  'cz': 1,
#  'dadan': 2,
#  'dl': 1,
#  'doge': 5,
#  'dt': 1,
#  'eb09': 1,
#  'edu': 1,
#  'eg2209': 1,
#  'eia': 3,
#  'eps': 1,
#  'eth': 2,
#  'fametal': 3,
#  'fda': 4,
#  'fed': 1,
#  'ff': 1,
#  'fob': 2,
#  'fomc': 3,
#  'ftx': 21,
#  'fw': 1,
#  'g7': 3,
#  'gazprom': 1,
#  'gdp': 12,
#  'genesis': 2,
#  'good': 3,
#  'hbsksy': 1,
#  'hebeea': 1,
#  'hemerdon': 1,
#  'hicp': 1,
#  'hpv': 3,
#  'http': 9,
#  'https': 1,
#  'huanqiu': 1,
#  'ic': 1,
#  'ice': 1,
#  'ie': 1,
#  'if': 1,
#  'ih': 1,
#  'im': 1,
#  'ine': 2,
#  'into1': 2,
#  'ism': 1,
#  'javid': 1,
#  'jz': 2,
#  'kdj': 2,
#  'kevin': 1,
#  'kucoin': 1,
#  'kusdiana': 2,
#  'l0': 1,
#  'l8': 1,
#  'layerzero': 1,
#  'lee': 1,
#  'lldpe': 1,
#  'lldpe2209': 1,
#  'lme': 2,
#  'lme0': 1,
#  'lu': 1,
#  'lucy': 1,
#  'luna': 1,
#  'lyx': 2,
#  'm2': 1,
#  'ma': 2,
#  'ma10': 1,
#  'macd': 2,
#  'management': 1,
#  'max': 1,
#  'mm': 2,
#  'mori': 1,
#  'msci': 1,
#  'mtbe': 1,
#  'mu5735': 1,
#  'multicoin': 1,
#  'mysteel': 10,
#  'n95': 1,
#  'nayib': 1,
#  'nbsp': 1,
#  'nhs': 1,
#  'nick': 3,
#  'nr2210': 1,
#  'ok': 1,
#  'one': 1,
#  'oversea': 1,
#  'p12': 1,
#  'p2209': 1,
#  'p3': 1,
#  'p4': 1,
#  'pais': 1,
#  'paradigm': 1,
#  'pb': 1,
#  'pb2209': 1,
#  'pcts': 1,
#  'pe': 4,
#  'pf09': 1,
#  'pg09': 1,
#  'pmi': 7,
#  'pon': 1,
#  'popo': 1,
#  'popping': 1,
#  'pp': 4,
#  'pp2209': 1,
#  'ppi': 1,
#  'pro': 1,
#  'ps': 1,
#  'pta': 14,
#  'pua': 1,
#  'pvc': 6,
#  'px': 4,
#  'q1593293305': 1,
#  'qp8': 1,
#  'qs': 1,
#  'qycy': 2,
#  'rap': 1,
#  'research': 1,
#  'rf': 1,
#  'river': 2,
#  'road': 1,
#  'ru2209': 1,
#  'sajid': 1,
#  'sbf': 2,
#  'sc': 1,
#  'sh': 1,
#  'silk': 1,
#  'silkroad': 1,
#  'sm5lcbzint8': 1,
#  'smm': 10,
#  'sophia': 1,
#  'sr209': 2,
#  'sr301': 1,
#  'strela': 1,
#  'suzhu': 1,
#  'sz300750': 1,
#  'ta2209': 1,
#  'tether': 4,
#  'ticad': 1,
#  'timiraos': 3,
#  'travel': 1,
#  'ttf': 2,
#  'tungsten': 1,
#  'usdt': 4,
#  'ust': 1,
#  'ventures': 1,
#  'vgo': 1,
#  'vtb': 1,
#  'west': 1,
#  'wood': 1,
#  'www': 1,
#  'xx': 1,
#  'y2209': 1,
#  'yj': 1,
#  'young': 1,
#  'yoy': 1,
#  'yz': 1,
#  'zd': 3,
#  'zdgz': 1,
#  'zn2209': 1,
#  'zx': 1,
#  '一下': 1,
#  '一个': 16,
#  '一个月': 3,
#  '一些': 1,
#  '一人': 1,
#  '一付': 1,
#  '一份': 1,
#  '一体': 1,
#  '一体化': 7,
#  '一切权利': 1,
#  '一千多': 1,
#  '一半': 1,
#  '一只': 1,
#  '一台': 1,
#  '一号': 1,
#  '一名': 1,
#  '一周': 3,
#  '一图': 1,
#  '一声令下': 1,
#  '一大批': 1,
#  '一天': 1,
#  '一头': 1,
#  '一套': 3,
#  '一如既往': 1,
#  '一季度': 4,
#  '一定': 16,
#  '一家': 3,
#  '一岁': 1,
#  '一市': 1,
#  '一带': 1,
#  '一帮': 1,
#  '一幅': 1,
#  '一年': 2,
#  '一年期': 2,
#  '一度': 1,
#  '一张白纸': 1,
#  '一所': 1,
#  '一批': 3,
#  '一抱': 1,
#  '一揽子': 1,
#  '一无是处': 1,
#  '一日': 1,
#  '一是': 1,
#  '一朝一夕': 1,
#  '一期': 4,
#  '一条': 3,
#  '一条条': 1,
#  '一来': 1,
#  '一杯': 1,
#  '一样': 3,
#  '一次': 4,
#  '一次性': 4,
#  '一步': 1,
#  '一步步': 2,
#  '一段': 1,
#  '一段时间': 4,
#  '一段落': 1,
#  '一波': 1,
#  '一点': 1,
#  '一班': 2,
#  '一瓢': 1,
#  '一百周年': 1,
#  '一直': 13,
#  '一种': 1,
#  '一秒': 1,
#  '一系列': 6,
#  '一级': 5,
#  '一线': 7,
#  '一组': 1,
#  '一网通': 1,
#  '一脚': 1,
#  '一致': 4,
#  '一般': 8,
#  '一词': 1,
#  '一起': 3,
#  '一路': 3,
#  '一轮': 1,
#  '一道道': 1,
#  '一部分': 1,
#  '丁烷': 2,
#  '七国集团': 2,
#  '七天': 1,
#  '七成': 2,
#  '万不得已': 1,
#  '万个': 5,
#  '万丰': 1,
#  '万人': 6,
#  '万亿': 8,
#  '万亿元': 6,
#  '万元': 4,
#  '万公里': 2,
#  '万及': 2,
#  '万吨': 170,
#  '万家': 4,
#  '万平方米': 1,
#  '万座': 1,
#  '万手': 4,
#  '万架': 1,
#  '万桶': 12,
#  '万物': 1,
#  '万美元': 1,
#  '万股': 1,
#  '万辆': 9,
#  '万达': 1,
#  '三个': 7,
#  '三产': 1,
#  '三千': 1,
#  '三周': 1,
#  '三圆': 1,
#  '三大': 5,
#  '三大期': 1,
#  '三季度': 1,
#  '三家': 2,
#  '三层': 1,
#  '三年': 5,
#  '三座': 2,
#  '三房': 1,
#  '三方': 2,
#  '三星': 1,
#  '三期': 1,
#  '三条': 1,
#  '三次': 1,
#  '三沙': 1,
#  '三省': 1,
#  '三箭': 2,
#  '三线': 4,
#  '三道': 1,
#  '上下游': 1,
#  '上个月': 2,
#  '上升': 12,
#  '上午': 4,
#  '上半年': 25,
#  '上周': 23,
#  '上周五': 6,
#  '上周四': 1,
#  '上周末': 2,
#  '上市': 5,
#  '上市公司': 1,
#  '上年': 9,
#  '上扬': 2,
#  '上报': 1,
#  '上探': 1,
#  '上方': 13,
#  '上旬': 2,
#  '上映': 1,
#  '上朝': 1,
#  '上期': 9,
#  '上沪胶': 1,
#  '上海': 12,
#  '上海地区': 1,
#  '上海石化': 3,
#  '上涨': 74,
#  '上涨幅度': 1,
#  '上游': 5,
#  '上破': 1,
#  '上线': 2,
#  '上行': 17,
#  '上证': 1,
#  '上证指数': 1,
#  '上调': 11,
#  '上轨': 1,
#  '上述': 1,
#  '上部': 1,
#  '上限': 1,
#  '下个月': 1,
#  '下半年': 3,
#  '下周': 2,
#  '下图': 1,
#  '下挫': 1,
#  '下方': 8,
#  '下旬': 5,
#  '下来': 1,
#  '下游': 34,
#  '下滑': 14,
#  '下称': 1,
#  '下移': 4,
#  '下行': 9,
#  '下调': 4,
#  '下跌': 15,
#  '下车': 1,
#  '下载': 3,
#  '下载安装': 1,
#  '下辖': 2,
#  '下达': 2,
#  '下降': 82,
#  '下雨': 1,
#  '下雨天': 1,
#  '不了': 1,
#  '不仅': 5,
#  '不仅仅': 1,
#  '不会': 8,
#  '不佳': 4,
#  '不偷': 1,
#  '不利于': 2,
#  '不到': 2,
#  '不及': 6,
#  '不变': 6,
#  '不可否认': 1,
#  '不同': 6,
#  '不增': 1,
#  '不够': 3,
#  '不好': 1,
#  '不如': 1,
#  '不少': 4,
#  '不得': 7,
#  '不扰': 1,
#  '不敢': 1,
#  '不断': 24,
#  '不断加强': 1,
#  '不断深入': 1,
#  '不明': 1,
#  '不明朗': 1,
#  '不是': 7,
#  '不曾': 1,
#  '不满情绪': 1,
#  '不用': 1,
#  '不看': 1,
#  '不确定性': 3,
#  '不管': 1,
#  '不胜枚举': 1,
#  '不能': 13,
#  '不良贷款': 1,
#  '不要': 6,
#  '不见': 1,
#  '不足': 9,
#  '不足以': 1,
#  '不过': 18,
#  '不锈钢': 13,
#  '不错': 1,
#  '不靠': 1,
#  '不齐': 1,
#  '与时俱进': 1,
#  '与此同时': 4,
#  '专业': 2,
#  '专卖店': 1,
#  '专家': 1,
#  '专注': 1,
#  '专班': 1,
#  '专用': 2,
#  '专用肥': 1,
#  '专精': 1,
#  '专访': 1,
#  '专门': 1,
#  '专项': 1,
#  '且锡价': 1,
#  '世乒赛': 1,
#  '世界': 12,
#  '世界屋脊': 1,
#  '世界贸易组织': 1,
#  '世界遗产': 1,
#  '丙烷': 2,
#  '业务': 11,
#  '业务管理': 1,
#  '业态': 3,
#  '业绩': 5,
#  '业者': 2,
#  '东京': 1,
#  '东北': 3,
#  '东南亚': 2,
#  '东家': 1,
#  '东山再起': 1,
#  '东数': 2,
#  ...}

# %%
word_freq.items()
# Out:
# dict_items([('00', 6), ('000713', 1), ('000998', 1), ('002041', 1), ('002385', 1), ('01', 10), ('02', 4), ('03', 4), ('04', 3), ('05', 4), ('06', 3), ('061', 1), ('07', 6), ('08', 4), ('081', 1), ('0824', 1), ('09', 16), ('10', 57), ('100', 19), ('1000', 5), ('10080', 1), ('101', 1), ('10180', 1), ('102', 3), ('1025', 1), ('10274', 1), ('10355', 1), ('104', 3), ('10410', 1), ('10455', 1), ('105', 1), ('10510', 1), ('10685', 1), ('107', 2), ('108', 1), ('1080', 1), ('10cm', 2), ('10g', 1), ('11', 49), ('110', 3), ('1100', 1), ('11089', 1), ('112', 2), ('115', 1), ('116', 1), ('11724', 1), ('1189', 1), ('119', 1), ('11998', 1), ('12', 37), ('120', 4), ('1200', 2), ('12000', 2), ('12010', 1), ('1210', 1), ('122', 1), ('12245', 1), ('12750', 1), ('1280', 1), ('13', 14), ('130', 1), ('13050', 1), ('130eflops', 1), ('1310', 1), ('131700', 1), ('133', 1), ('13300', 1), ('13500', 1), ('136', 2), ('1360', 1), ('13686', 1), ('13817426131', 1), ('1383', 3), ('1399', 1), ('14', 17), ('1400', 3), ('1420', 1), ('145', 1), ('1477', 1), ('14815', 1), ('15', 17), ('150', 3), ('1500', 6), ('15050', 1), ('15125', 1), ('152', 1), ('15200', 1), ('15305', 1), ('15390', 1), ('15400', 1), ('15459', 1), ('155', 1), ('156', 2), ('15780', 1), ('1597', 1), ('15cm', 1), ('16', 7), ('16200', 1), ('1628', 1), ('163', 1), ('1650', 1), ('1655', 2), ('1660', 1), ('16600', 3), ('1663', 1), ('1665', 1), ('1675', 3), ('168', 1), ('1680', 3), ('1681', 1), ('1685', 2), ('1690', 2), ('16900', 2), ('169060', 1), ('17', 13), ('1700', 1), ('17000', 1), ('171890', 1), ('17300', 1), ('1733', 1), ('174', 1), ('1749', 1), ('1760', 1), ('177', 2), ('18', 17), ('180', 4), ('1800', 3), ('181000', 1), ('182', 1), ('182650', 1), ('18400', 1), ('184300', 1), ('1844', 1), ('1850', 1), ('1867', 2), ('18730', 1), ('189', 1), ('18983967167', 1), ('19', 15), ('1900', 1), ('1903', 1), ('194', 1), ('195230', 1), ('196000', 1), ('197', 1), ('197000', 1), ('1980', 2), ('198000', 1), ('199', 1), ('20', 28), ('200', 10), ('2000', 2), ('20000', 1), ('200000', 1), ('2002', 1), ('2004', 1), ('2012', 1), ('2013', 1), ('2015', 1), ('2016', 3), ('2018', 2), ('2019', 2), ('2020', 21), ('2021', 46), ('2022', 56), ('2023', 9), ('2024', 5), ('2025', 6), ('203', 1), ('2035', 1), ('2050', 1), ('2097', 1), ('21', 18), ('210', 1), ('211', 2), ('212', 1), ('2141', 1), ('215', 3), ('217', 1), ('2173', 1), ('219', 1), ('21915', 1), ('22', 23), ('220', 2), ('2200', 1), ('2207', 1), ('22086', 1), ('2209', 8), ('2210', 1), ('222', 1), ('224', 1), ('2246', 1), ('2249', 1), ('225', 1), ('2250', 1), ('2254', 1), ('2272', 1), ('229', 1), ('23', 10), ('230', 5), ('2300', 1), ('23166', 1), ('2339', 1), ('2340', 1), ('23500', 1), ('2354', 1), ('23570', 1), ('23610', 1), ('23670', 1), ('237', 1), ('23710', 1), ('23780', 1), ('23850', 1), ('24', 20), ('246', 1), ('247', 1), ('249', 1), ('25', 28), ('250', 1), ('2500', 2), ('25131', 1), ('2519', 1), ('2550', 1), ('2566', 1), ('258', 1), ('259', 1), ('26', 11), ('2600', 1), ('2613', 1), ('2640', 1), ('2650', 3), ('2672', 1), ('2680', 1), ('27', 14), ('2700', 3), ('2710', 1), ('27100', 2), ('2720', 1), ('273', 1), ('2730', 1), ('274', 1), ('2740', 1), ('2745', 1), ('2748', 1), ('2750', 3), ('2760', 1), ('2766', 1), ('2768', 1), ('2780', 1), ('27894', 1), ('28', 41), ('280', 1), ('2800', 1), ('2847', 1), ('2850', 2), ('2860', 1), ('29', 12), ('2900', 2), ('293087308', 1), ('2950', 2), ('2970', 1), ('2izti', 1), ('30', 23), ('300', 10), ('3000', 1), ('300087', 1), ('302', 1), ('304', 3), ('3050', 1), ('3061', 1), ('31', 8), ('3100', 1), ('3149', 1), ('3150', 1), ('316l', 1), ('3180', 1), ('3187', 1), ('32', 4), ('320', 1), ('3212', 1), ('3221', 1), ('33', 6), ('330', 4), ('3300', 1), ('3309', 1), ('3346', 1), ('3350', 1), ('336', 1), ('3386', 1), ('34', 10), ('340', 1), ('3402', 1), ('3430', 1), ('3460', 1), ('348', 1), ('3480', 1), ('35', 13), ('355', 1), ('3581', 1), ('36', 9), ('360', 1), ('365', 1), ('366', 1), ('37', 10), ('371', 1), ('374', 1), ('38', 10), ('380', 1) ...

# %%
# 观察词袋模型的词频技术结果 True从大到小
sorted(word_freq.items(),key=lambda x: x[1], reverse=True)
# Out:
# [('万吨', 170),
#  ('市场', 168),
#  ('库存', 103),
#  ('中国', 93),
#  ('预期', 92),
#  ('需求', 88),
#  ('下降', 82),
#  ('电子', 82),
#  ('加息', 75),
#  ('同比', 75),
#  ('上涨', 74),
#  ('价格', 74),
#  ('环比', 74),
#  ('增长', 72),
#  ('亿元', 71),
#  ('经济', 70),
#  ('反弹', 69),
#  ('国内', 69),
#  ('方面', 69),
#  ('继续', 69),
#  ('现货', 68),
#  ('重要', 65),
#  ('企业', 63),
#  ('合约', 62),
#  ('美联储', 62),
#  ('行情', 62),
#  ('政策', 60),
#  ('10', 57),
#  ('出口', 57),
#  ('2022', 56),
#  ('期货', 55),
#  ('关注', 54),
#  ('美元', 54),
#  ('目前', 53),
#  ('发展', 52),
#  ('预计', 52),
#  ('数据', 51),
#  ('11', 49),
#  ('公司', 49),
#  ('交易', 48),
#  ('报告', 48),
#  ('影响', 47),
#  ('2021', 46),
#  ('增加', 46),
#  ('持续', 46),
#  ('策略', 45),
#  ('郑州', 45),
#  ('数字', 44),
#  ('装置', 44),
#  ('产量', 43),
#  ('考生', 43),
#  ('近期', 43),
#  ('美国', 42),
#  ('28', 41),
#  ('减少', 41),
#  ('可能', 41),
#  ('显示', 41),
#  ('原油', 40),
#  ('城市', 40),
#  ('建设', 39),
#  ('来看', 38),
#  ('重庆', 38),
#  ('12', 37),
#  ('主要', 37),
#  ('截至', 37),
#  ('计划', 37),
#  ('资讯', 37),
#  ('国家', 36),
#  ('建议', 36),
#  ('震荡', 36),
#  ('复盘', 35),
#  ('开工率', 35),
#  ('短期', 35),
#  ('下游', 34),
#  ('风险', 34),
#  ('主力', 33),
#  ('成本', 33),
#  ('月份', 33),
#  ('进一步', 33),
#  ('全球', 32),
#  ('开工', 32),
#  ('我们', 32),
#  ('检修', 32),
#  ('玉米', 32),
#  ('压力', 31),
#  ('当前', 31),
#  ('通胀', 31),
#  ('产品', 30),
#  ('发布', 30),
#  ('以来', 29),
#  ('回落', 29),
#  ('地区', 29),
#  ('大幅', 29),
#  ('支撑', 29),
#  ('本周', 29),
#  ('涨幅', 29),
#  ('维持', 29),
#  ('重启', 29),
#  ('20', 28),
#  ('25', 28),
#  ('整体', 28),
#  ('疫情', 28),
#  ('75', 27),
#  ('左右', 27),
#  ('水平', 27),
#  ('50', 26),
#  ('信息', 26),
#  ('放缓', 26),
#  ('超过', 26),
#  ('上半年', 25),
#  ('主流', 25),
#  ('以及', 25),
#  ('报价', 25),
#  ('考试', 25),
#  ('落地', 25),
#  ('行业', 25),
#  ('表示', 25),
#  ('5g', 24),
#  ('不断', 24),
#  ('为主', 24),
#  ('实现', 24),
#  ('提升', 24),
#  ('收于', 24),
#  ('改善', 24),
#  ('有所', 24),
#  ('银行', 24),
#  ('项目', 24),
#  ('22', 23),
#  ('30', 23),
#  ('上周', 23),
#  ('依然', 23),
#  ('全国', 23),
#  ('处于', 23),
#  ('已经', 23),
#  ('指数', 23),
#  ('有限公司', 23),
#  ('期价', 23),
#  ('走势', 23),
#  ('附近', 23),
#  ('cpi', 22),
#  ('供应', 22),
#  ('公布', 22),
#  ('其中', 22),
#  ('回升', 22),
#  ('基点', 22),
#  ('开户', 22),
#  ('情况', 22),
#  ('考场', 22),
#  ('资金', 22),
#  ('进口', 22),
#  ('2020', 21),
#  ('ftx', 21),
#  ('停车', 21),
#  ('出现', 21),
#  ('同时', 21),
#  ('技术', 21),
#  ('投资', 21),
#  ('生产', 21),
#  ('网络', 21),
#  ('进入', 21),
#  ('随着', 21),
#  ('24', 20),
#  ('产业', 20),
#  ('基础设施', 20),
#  ('宏观', 20),
#  ('工业', 20),
#  ('开始', 20),
#  ('情绪', 20),
#  ('操作', 20),
#  ('英国', 20),
#  ('资产', 20),
#  ('达到', 20),
#  ('部分', 20),
#  ('100', 19),
#  ('中心', 19),
#  ('任何', 19),
#  ('周四', 19),
#  ('明显', 19),
#  ('没有', 19),
#  ('波动', 19),
#  ('相关', 19),
#  ('规模', 19),
#  ('逐步', 19),
#  ('21', 18),
#  ('不过', 18),
#  ('以上', 18),
#  ('会议', 18),
#  ('保持', 18),
#  ('偏弱', 18),
#  ('增速', 18),
#  ('工作', 18),
#  ('政府', 18),
#  ('石化', 18),
#  ('综合', 18),
#  ('美豆', 18),
#  ('订单', 18),
#  ('调整', 18),
#  ('跟随', 18),
#  ('钢厂', 18),
#  ('14', 17),
#  ('15', 17),
#  ('18', 17),
#  ('上行', 17),
#  ('刘雨昕', 17),
#  ('同期', 17),
#  ('延续', 17),
#  ('成交', 17),
#  ('房地产', 17),
#  ('期货市场', 17),
#  ('未来', 17),
#  ('空间', 17),
#  ('第一', 17),
#  ('表现', 17),
#  ('趋势', 17),
#  ('进行', 17),
#  ('09', 16),
#  ('40', 16),
#  ('一个', 16),
#  ('一定', 16),
#  ('低于', 16),
#  ('俄罗斯', 16),
#  ('利润', 16),
#  ('区间', 16),
#  ('好转', 16),
#  ('无锡', 16),
#  ('最大', 16),
#  ('根据', 16),
#  ('沥青', 16),
#  ('社会', 16),
#  ('终端', 16),
#  ('考点', 16),
#  ('自己', 16),
#  ('规划', 16),
#  ('较大', 16),
#  ('连续', 16),
#  ('长沙', 16),
#  ('需要', 16),
#  ('黄金', 16),
#  ('19', 15),
#  ('45', 15),
#  ('59', 15),
#  ('72', 15),
#  ('下跌', 15),
#  ('供给', 15),
#  ('偏强', 15),
#  ('健康', 15),
#  ('分别', 15),
#  ('可以', 15),
#  ('国际', 15),
#  ('基建', 15),
#  ('年末', 15),
#  ('应用', 15),
#  ('总量', 15),
#  ('恢复', 15),
#  ('截止', 15),
#  ('推动', 15),
#  ('支持', 15),
#  ('新型', 15),
#  ('时间', 15),
#  ('有限', 15),
#  ('步伐', 15),
#  ('港口', 15),
#  ('炼厂', 15),
#  ('符合', 15),
#  ('13', 14),
#  ('27', 14),
#  ('pta', 14),
#  ('下滑', 14),
#  ('其他', 14),
#  ('减产', 14),
#  ('利率', 14),
#  ('力度', 14),
#  ('加快', 14),
#  ('华东', 14),
#  ('基本面', 14),
#  ('工厂', 14),
#  ('成为', 14),
#  ('我国', 14),
#  ('推进', 14),
#  ('智慧', 14),
#  ('最新', 14),
#  ('有效', 14),
#  ('核酸', 14),
#  ('海外', 14),
#  ('消费', 14),
#  ('淀粉', 14),
#  ('监管', 14),
#  ('资源', 14),
#  ('通过', 14),
#  ('销售', 14),
#  ('17', 13),
#  ('35', 13),
#  ('一直', 13),
#  ('上方', 13),
#  ('不能', 13),
#  ('不锈钢', 13),
#  ('产能', 13),
#  ('今年', 13),
#  ('优势', 13),
#  ('修复', 13),
#  ('利好', 13),
#  ('前值', 13),
#  ('印尼', 13),
#  ('地产', 13),
#  ('央行', 13),
#  ('存在', 13),
#  ('对于', 13),
#  ('小幅', 13),
#  ('带动', 13),
#  ('日当周', 13),
#  ('机构', 13),
#  ('百分点', 13),
#  ('盎司', 13),
#  ('盘面', 13),
#  ('稳定', 13),
#  ('负荷', 13),
#  ('采购', 13),
#  ('青岛', 13),
#  ('29', 12),
#  ('gdp', 12),
#  ('万桶', 12),
#  ('上升', 12),
#  ('上海', 12),
#  ('世界', 12),
#  ('互联网', 12),
#  ('但是', 12),
#  ('低位', 12),
#  ('分析', 12),
#  ('受到', 12),
#  ('天气', 12),
#  ('实施', 12),
#  ('客户', 12),
#  ('开发', 12),
#  ('扩大', 12),
#  ('新能源', 12),
#  ('期权', 12),
#  ('欧洲央行', 12),
#  ('烟草', 12),
#  ('相对', 12),
#  ('种子', 12),
#  ('突破', 12),
#  ('管理', 12),
#  ('经济衰退', 12),
#  ('谨慎', 12),
#  ('货源', 12),
#  ('贷款', 12),
#  ('走高', 12),
#  ('转基因', 12),
#  ('释放', 12),
#  ('问题', 12),
#  ('26', 11),
#  ('53', 11),
#  ('60', 11),
#  ('90', 11),
#  ('cn', 11),
#  ('上调', 11),
#  ('业务', 11),
#  ('个人', 11),
#  ('企稳', 11),
#  ('作为', 11),
#  ('供需', 11),
#  ('创新', 11),
#  ('利空', 11),
#  ('包括', 11),
#  ('去库', 11),
#  ('团队', 11),
#  ('均线', 11),
#  ('山东', 11),
#  ('底部', 11),
#  ('总额', 11),
#  ('所以', 11),
#  ('持平', 11),
#  ('提供', 11),
#  ('提振', 11),
#  ('新增', 11),
#  ('有色', 11),
#  ('检测', 11),
#  ('正式', 11),
#  ('汽车', 11),
#  ('油脂', 11),
#  ('燃料油', 11),
#  ('状态', 11),
#  ('目标', 11),
#  ('研发', 11),
#  ('累计', 11),
#  ('纯碱', 11),
#  ('统计', 11),
#  ('聚酯', 11),
#  ('观望', 11),
#  ('资本', 11),
#  ('较为', 11),
#  ('运行', 11),
#  ('这个', 11),
#  ('防控', 11),
#  ('阶段', 11),
#  ('高于', 11),
#  ('鲍威尔', 11),
#  ('01', 10),
#  ('200', 10),
#  ('23', 10),
#  ('300', 10),
#  ('34', 10),
#  ('37', 10),
#  ('38', 10),
#  ('70', 10),
#  ('93', 10),
#  ('mysteel', 10),
#  ('smm', 10),
#  ('两个', 10),
#  ('之前', 10),
#  ('今日', 10),
#  ('做好', 10),
#  ('关口', 10),
#  ('再生', 10),
#  ('前期', 10),
#  ('北京', 10),
#  ('去年同期', 10),
#  ('参加考试', 10),
#  ('变化', 10),
#  ('周三', 10),
#  ('就业', 10),
#  ('层面', 10),
#  ('巴西', 10),
#  ('幅度', 10),
#  ('平台', 10),
#  ('得到', 10),
#  ('成都', 10),
#  ('所有', 10),
#  ('投资者', 10),
#  ('担忧', 10),
#  ('措施', 10),
#  ('提前', 10),
#  ('数量', 10),
#  ('新低', 10),
#  ('月末', 10),
#  ('核心', 10),
#  ('棕榈油', 10),
#  ('欧元区', 10),
#  ('油价', 10),
#  ('淡季', 10),
#  ('种业', 10),
#  ('结果', 10),
#  ('考研', 10),
#  ('西部', 10),
#  ('贵金属', 10),
#  ('迎来', 10),
#  ('面临', 10),
#  ('2023', 9),
#  ('36', 9),
#  ('65', 9),
#  ('75bp', 9),
#  ('http', 9),
#  ('万辆', 9),
#  ('上年', 9),
#  ('上期', 9),
#  ('下行', 9),
#  ('不足', 9),
#  ('交易日', 9),
#  ('产业链', 9),
#  ('人民币', 9),
#  ('亿美元', 9),
#  ('内容', 9),
#  ('制造', 9),
#  ('升级', 9),
#  ('取得', 9),
#  ('因为', 9),
#  ('基差', 9),
#  ('复产', 9),
#  ('完成', 9),
#  ('山娃', 9),
#  ('年底', 9),
#  ('广东', 9),
#  ('收盘', 9),
#  ('智能', 9),
#  ('月底', 9),
#  ('有望', 9),
#  ('构成', 9),
#  ('正在', 9),
#  ('比较', 9),
#  ('水稻', 9),
#  ('玻璃', 9),
#  ('生物', 9),
#  ('科技', 9),
#  ('积极', 9),
#  ('获得', 9),
#  ('融资', 9),
#  ('行动', 9),
#  ('还是', 9),
#  ('金融', 9),
#  ('长期', 9),
#  ('阻力', 9),
#  ('2209', 8),
#  ('31', 8),
#  ('54', 8),
#  ('64', 8),
#  ('81', 8),
#  ('一般', 8),
#  ('万亿', 8),
#  ('下方', 8),
#  ('不会', 8),
#  ('中辉', 8),
#  ('乙二醇', 8),
#  ('交易所', 8),
#  ('他们', 8),
#  ('价值', 8),
#  ('价格上涨', 8),
#  ('优良率', 8),
#  ('低水平', 8),
#  ('作用', 8),
#  ('信心', 8),
#  ('关于', 8),
#  ('出口量', 8),
#  ('加大', 8),
#  ('区域', 8),
#  ('厂家', 8),
#  ('合计', 8),
#  ('后续', 8),
#  ('商品', 8),
#  ('声明', 8),
#  ('带来', 8),
#  ('建成', 8),
#  ('弱势', 8),
#  ('态势', 8),
#  ('战略', 8),
#  ('提高', 8),
#  ('摩尔', 8),
#  ('放量', 8),
#  ('教育', 8),
#  ('数据中心', 8),
#  ('方向', 8),
#  ('日均', 8),
#  ('时候', 8),
#  ('欧盟', 8),
#  ('消息', 8),
#  ('渗透率', 8),
#  ('焦炭', 8),
#  ('禁止', 8),
#  ('考虑', 8),
#  ('股份', 8),
#  ('能力', 8),
#  ('能够', 8),
#  ('要求', 8),
#  ('贸易', 8),
#  ('转型', 8),
#  ('边际', 8),
#  ('进出口', 8),
#  ('通知', 8),
#  ('防疫', 8),
#  ('陆续', 8),
#  ('首次', 8),
#  ('16', 7),
#  ('43', 7),
#  ('51', 7),
#  ('58', 7),
#  ('62', 7),
#  ('68', 7),
#  ('78', 7),
#  ('pmi', 7),
#  ('一体化', 7),
#  ('一线', 7),
#  ('三个', 7),
#  ('不得', 7),
#  ('不是', 7),
#  ('东方', 7),
#  ('之下', 7),
#  ('乌克兰', 7),
#  ('乡村', 7),
#  ('亏损', 7),
#  ('以下', 7),
#  ('偏低', 7),
#  ('做空', 7),
#  ('全面', 7),
#  ('再度', 7),
#  ('出货', 7),
#  ('加速', 7),
#  ('动能', 7),
#  ('北方', 7),
#  ('医疗', 7),
#  ('历史', 7),
#  ('及其', 7),
#  ('另外', 7),
#  ('向上', 7),
#  ('品牌', 7),
#  ('回到', 7),
#  ('国务院', 7),
#  ('均价', 7),
#  ('基本', 7),
#  ('基础', 7),
#  ('增强', 7),
#  ('天津', 7),
#  ('如果', 7),
#  ('官方', 7),
#  ('导致', 7),
#  ('小时', 7),
#  ('属于', 7),
#  ('年期', 7),
#  ('形成', 7),
#  ('思路', 7),
#  ('意愿', 7),
#  ('手机', 7),
#  ('收益率', 7),
#  ('放慢', 7),
#  ('暴雷', 7),
#  ('更加', 7),
#  ('期待', 7),
#  ('来源', 7),
#  ('板块', 7),
#  ('样本', 7),
#  ('此前', 7),
#  ('注意', 7),
#  ('流感', 7),
#  ('消化', 7),
#  ('用户', 7),
#  ('研究', 7),
#  ('系统', 7),
#  ('结束', 7),
#  ('缩小', 7),
#  ('老师', 7),
#  ('考试院', 7),
#  ('聚烯烃', 7),
#  ('股指', 7),
#  ('胶价', 7),
#  ('范围', 7),
#  ('虽然', 7),
#  ('表明', 7),
#  ('西班牙', 7),
#  ('覆盖', 7),
#  ('调研', 7),
#  ('货币政策', 7),
#  ('走弱', 7),
#  ('赴考', 7),
#  ('跌幅', 7),
#  ('近日', 7),
#  ('这是', 7),
#  ('这样', 7),
#  ('重点', 7),
#  ('高位', 7),
#  ('00', 6),
#  ('07', 6),
#  ('1500', 6),
#  ('2025', 6),
#  ('33', 6),
#  ('4000', 6),
#  ('42', 6),
#  ('46', 6),
#  ('52', 6),
#  ('56', 6),
#  ('67', 6),
#  ('74', 6),
#  ('95', 6),
#  ('pvc', 6),
#  ('一系列', 6),
#  ('万人', 6),
#  ('万亿元', 6),
#  ('上周五', 6),
#  ('不及', 6),
#  ('不变', 6),
#  ('不同', 6),
#  ('不要', 6),
#  ('中央', 6),
#  ('中期', 6),
#  ('之间', 6),
#  ('了解', 6),
#  ('事项', 6),
#  ('交割', 6),
#  ('交投', 6),
#  ('人员', 6),
#  ('人民', 6),
#  ('仍然', 6),
#  ('价差', 6),
#  ('体系', 6),
#  ('依旧', 6),
#  ('促进', 6),
#  ('公告', 6),
#  ('具有', 6),
#  ('农作物', 6),
#  ('准备', 6),
#  ('减仓', 6),
#  ('刘宇', 6),
#  ('办理', 6),
#  ('加强', 6),
#  ('十四五', 6),
#  ('华北', 6),
#  ('华南', 6),
#  ('协议', 6),
#  ('原因', 6),
#  ('原料', 6),
#  ('反超', 6),
#  ('反转', 6),
#  ('叠加', 6),
#  ('口罩', 6),
#  ('同样', 6),
#  ('品种', 6),
#  ('回复', 6),
#  ('回暖', 6),
#  ('回调', 6),
#  ('回购', 6),
#  ('因素', 6),
#  ('培育', 6),
#  ('基于', 6),
#  ('增量', 6),
#  ('多增', 6),
#  ('大宗', 6),
#  ('大家', 6),
#  ('大涨', 6),
#  ('天胶', 6),
#  ('安全', 6),
#  ('宣布', 6),
#  ('密集', 6),
#  ('尽管', 6),
#  ('巴尔迪维', 6),
#  ('干旱', 6),
#  ('平均', 6),
#  ('平稳', 6),
#  ('年度', 6),
#  ('强劲', 6),
#  ('强国', 6),
#  ('很多', 6),
#  ('德国', 6),
#  ('总体', 6),
#  ('成功', 6),
#  ('成品', 6),
#  ('承压', 6),
#  ('按照', 6),
#  ('控制', 6),
#  ('提出', 6),
#  ('收入', 6),
#  ('收窄', 6),
#  ('收紧', 6),
#  ('数字化', 6),
#  ('整理', 6),
#  ('文件', 6),
#  ('日减', 6),
#  ('明确', 6),
#  ('暂时', 6),
#  ('服务业', 6),
#  ('期间', 6),
#  ('机制', 6),
#  ('材料', 6),
#  ('来自', 6),
#  ('概念', 6),
#  ('欧洲', 6),
#  ('止损', 6),
#  ('此外', 6),
#  ('比亚迪', 6),
#  ('河北', 6),
#  ('浙江', 6),
#  ('深加工', 6),
#  ('热卷', 6),
#  ('玉林', 6),
#  ('现在', 6),
#  ('甲醇', 6),
#  ('疫苗', 6),
#  ('白银', 6),
#  ('盘中', 6),
#  ('短纤', 6),
#  ('短线', 6),
#  ('纸厂', 6),
#  ('纸浆', 6),
#  ('经营', 6),
#  ('绝对', 6),
#  ('缩减', 6),
#  ('联系', 6),
#  ('股价', 6),
#  ('育种', 6),
#  ('能否', 6),
#  ('自闭症', 6),
#  ('补充', 6),
#  ('豆粕', 6),
#  ('质量', 6),
#  ('转好', 6),
#  ('过程', 6),
#  ('进口量', 6),
#  ('连粕', 6),
#  ('选择', 6),
#  ('通道', 6),
#  ('部门', 6),
#  ('重心', 6),
#  ('铁矿', 6),
#  ('铁矿石', 6),
#  ('阳性', 6),
#  ('降幅', 6),
#  ('集体', 6),
#  ('非常', 6),
#  ('靴子', 6),
#  ('风云榜', 6),
#  ('高硫', 6),
#  ('高质量', 6),
#  ('高速', 6),
#  ('1000', 5),
#  ('2024', 5),
#  ('230', 5),
#  ('41', 5),
#  ('55', 5),
#  ('85', 5),
#  ('87', 5),
#  ('89', 5),
#  ('92', 5),
#  ('aa', 5),
#  ('coinbase', 5),
#  ('doge', 5),
#  ('一级', 5),
#  ('万个', 5),
#  ('三大', 5),
#  ('三年', 5),
#  ('上市', 5),
#  ('上游', 5),
#  ('下旬', 5),
#  ('不仅', 5),
#  ('业绩', 5),
#  ('为了', 5),
#  ('九价', 5),
#  ('买入', 5),
#  ('产销', 5),
#  ('仓单', 5),
#  ('价位', 5),
#  ('传统', 5),
#  ('位置', 5),
#  ('低硫', 5),
#  ('作物', 5),
#  ('佩戴', 5),
#  ('使用', 5),
#  ('保护', 5),
#  ('保障', 5),
#  ('光伏', 5),
#  ('全程', 5),
#  ('全部', 5),
#  ('再次', 5),
#  ('冲击', 5),
#  ('制造业', 5),
#  ('加上', 5),
#  ('千克', 5),
#  ('升至', 5),
#  ('南京', 5),
#  ('即可', 5),
#  ('压制', 5),
#  ('发行', 5),
#  ('变动', 5),
#  ('召开', 5),
#  ('可能性', 5),
#  ('司机', 5),
#  ('合适', 5),
#  ('同比增加', 5),
#  ('后市', 5),
#  ('后期', 5),
#  ('呈现', 5),
#  ('呜呜', 5),
#  ('周二', 5),
#  ('因此', 5),
#  ('国债', 5),
#  ('在于', 5),
#  ('地方', 5),
#  ('坚持', 5),
#  ('培训', 5),
#  ('增加值', 5),
#  ('增幅', 5),
#  ('声音', 5),
#  ('复苏', 5),
#  ('外贸', 5),
#  ('大豆', 5),
#  ('好于', 5),
#  ('如期', 5),
#  ('存款', 5),
#  ('安排', 5),
#  ('完全', 5),
#  ('小麦', 5),
#  ('尤其', 5),
#  ('就是', 5),
#  ('展开', 5),
#  ('工业品', 5),
#  ('差距', 5),
#  ('布局', 5),
#  ('年内', 5),
#  ('开放', 5),
#  ('弱于', 5),
#  ('强势', 5),
#  ('强化', 5),
#  ('当地', 5),
#  ('形势', 5),
#  ('必须', 5),
#  ('快速', 5),
#  ('成材', 5),
#  ('手续费', 5),
#  ('执行', 5),
#  ('投研', 5),
#  ('报考', 5),
#  ('招生', 5),
#  ('持有', 5),
#  ('持续性', 5),
#  ('提醒', 5),
#  ('支撑位', 5),
#  ('收涨', 5),
#  ('改革', 5),
#  ('政治局', 5),
#  ('新兴产业', 5),
#  ('新闻', 5),
#  ('新高', 5),
#  ('日本', 5),
#  ('时代', 5),
#  ('显著', 5),
#  ('暗示', 5),
#  ('更是', 5),
#  ('最高', 5),
#  ('本人', 5),
#  ('杂交种', 5),
#  ('棉花', 5),
#  ('概率', 5),
#  ('欧元', 5),
#  ('正常', 5),
#  ('比如', 5),
#  ('民用气', 5),
#  ('江苏', 5),
#  ('河北省', 5),
#  ('流程', 5),
#  ('测试', 5),
#  ('浮法玻璃', 5),
#  ('港量', 5),
#  ('焦化', 5),
#  ('焦煤', 5),
#  ('熊市', 5),
#  ('父亲', 5),
#  ('玉米种子', 5),
#  ('生产线', 5),
#  ('生活', 5),
#  ('生铁', 5),
#  ('生长', 5),
#  ('申请', 5),
#  ('疲软', 5),
#  ('相信', 5),
#  ('看到', 5),
#  ('真的', 5),
#  ('确保', 5),
#  ('程度', 5),
#  ('窄幅', 5),
#  ('筷子', 5),
#  ('算力', 5),
#  ('精炼', 5),
#  ('缓慢', 5),
#  ('缓解', 5),
#  ('股权', 5),
#  ('能源', 5),
#  ('自身', 5),
#  ('节奏', 5),
#  ('蓝皮书', 5),
#  ('补库', 5),
#  ('观点', 5),
#  ('解决', 5),
#  ('言论', 5),
#  ('评级', 5),
#  ('责任', 5),
#  ('走强', 5),
#  ('超话', 5),
#  ('越来越', 5),
#  ('转发', 5),
#  ('还有', 5),
#  ('这些', 5),
#  ('进展', 5),
#  ('通信', 5),
#  ('通关', 5),
#  ('速度', 5),
#  ('采取', 5),
#  ('防护', 5),
#  ('阶段性', 5),
#  ('降雨', 5),
#  ('限度', 5),
#  ('领先', 5),
#  ('领域', 5),
#  ('题材', 5),
#  ('食糖', 5),
#  ('高炉', 5),
#  ('齐鲁石化', 5),
#  ('02', 4),
#  ('03', 4),
#  ('05', 4),
#  ('08', 4),
#  ('120', 4),
#  ('180', 4),
#  ('32', 4),
#  ('330', 4),
#  ('3900', 4),
#  ('400', 4),
#  ('47', 4),
#  ('63', 4),
#  ('69', 4),
#  ('73', 4),
#  ('76', 4),
#  ('80', 4),
#  ('83', 4),
#  ('91', 4),
#  ('99', 4),
#  ('fda', 4),
#  ('pe', 4),
#  ('pp', 4),
#  ('px', 4),
#  ('tether', 4),
#  ('usdt', 4),
#  ('一季度', 4),
#  ('一期', 4),
#  ('一次', 4),
#  ('一次性', 4),
#  ...]

# %%
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\shang shichen\appdata\roaming\python\python39\site-packages (1.9.4)
# Requirement already satisfied: matplotlib in d:\download\anaconda\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in d:\download\anaconda\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in d:\download\anaconda\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in d:\download\anaconda\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in d:\download\anaconda\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in d:\download\anaconda\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\download\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\download\anaconda\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\download\anaconda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\download\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import matplotlib.pyplot as plt

wc = WordCloud(
    width=1200,
    height=800,
    max_words=100, #设置最大显示的词数
    colormap='Blues',
    background_color='white'
    ,font_path='simhei.ttf'
).generate_from_frequencies(word_freq)

plt.figure(figsize=(10,5))

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
